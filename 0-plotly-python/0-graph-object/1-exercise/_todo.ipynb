# %% [markdown]
# ### Exercise
#
# Create an **interactive pie chart** using `go.Pie` that:
#
# 1. Displays each category's **percentage and label** on the slice
# 2. **Pulls out** the largest slice (Electronics) by `0.1`
# 3. Sets the **hole** to `0.3` (donut style)
# 4. Title: `"Sales Distribution by Category"`
# 5. Use **update methods style** (no magic underscore)
#
# > 💡 Hint: Check [`/reference/pie/`](https://plotly.com/python/reference/pie/)
# > for `pull`, `hole`, and `textinfo` properties

# %%
# data
labels = ["Electronics", "Clothing", "Food", "Books", "Toys"]
values = [45200, 31800, 27500, 15400, 19700]

import plotly.graph_objects as go
