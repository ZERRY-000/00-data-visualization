# %% [markdown]
# #  Free Map Styles (No Token Required)

# %%
pdk.map_styles.LIGHT       # light/white basemap
pdk.map_styles.DARK        # dark basemap  
pdk.map_styles.ROAD        # road/voyager style
pdk.map_styles.SATELLITE   # satellite imagery
